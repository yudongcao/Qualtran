# %% [markdown]
# # Phase Product

# %%
from qualtran import Bloq, CompositeBloq, BloqBuilder, Signature, Register
from qualtran import QBit, QInt, QUInt, QAny
from qualtran.drawing import show_bloq, show_call_graph, show_counts_sigma
from typing import *
import numpy as np
import sympy
import cirq
from PhaseProduct import Base2, Base3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6 import sympy
#       7 import cirq
# ----> 8 from PhaseProduct import Base2, Base3
#
# File ~/Documents/Quantum/Qualtran-1/qualtran/bloqs/arithmetic/PhaseProduct.py:5
#       3 from functools import cached_property
#       4 from qualtran import Bloq, Signature, QInt, Register, QBit, BloqBuilder, Soquet, SoquetT
# ----> 5 from qualtran.bloqs.basic_gates.rotation import CZPowGate, CRz
#       6 from qualtran.drawing import show_bloq
#       7 #from qualtran.simulation.classical_sim import add_ints, ClassicalValT
#
# ImportError: cannot import name 'CRz' from 'qualtran.bloqs.basic_gates.rotation' (/Users/manuelarivas/Documents/Quantum/Qualtran-3/qualtran/bloqs/basic_gates/rotation.py)

# %%
Base2 = Base2(phi=sympy.pi/4)
Base3 = Base3(phi=sympy.pi/4)

# %%
TBase2 = Base2.tensor_contract()
TBase3 = Base3.tensor_contract()
# Out:
# ---------------------------------------------------------------------------
# BloqError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 TBase2 = Base2.tensor_contract()
#       2 TBase3 = Base3.tensor_contract()
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/bloq.py:247, in Bloq.tensor_contract(self)
#     238 """Return a contracted, dense ndarray representing this bloq.
#     239
#     240 This constructs a tensor network and then contracts it according to our registers,
#    (...)    243 of (right, left) indices.
#     244 """
#     245 from qualtran.simulation.tensor import bloq_to_dense
# --> 247 return bloq_to_dense(self)
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/simulation/tensor/_dense.py:60, in bloq_to_dense(bloq)
#      46 """Return a contracted, dense ndarray representing the composite bloq.
#      47
#      48 The public version of this function is available as the `Bloq.tensor_contract()`
#    (...)     57 `cbloq_to_quimb` and `TensorNetwork.to_dense` directly.
#      58 """
#      59 cbloq = bloq.as_composite_bloq()
# ---> 60 tn, _ = cbloq_to_quimb(cbloq)
#      61 inds = get_right_and_left_inds(cbloq.signature)
#      63 if inds:
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/simulation/tensor/_quimb.py:99, in cbloq_to_quimb(cbloq, pos)
#      86 inc_d = _cxn_to_soq_dict(
#      87     bloq.signature.lefts(),
#      88     incoming,
#      89     get_me=lambda cxn: cxn.right,
#      90     get_assign=lambda cxn: cxn.left,
#      91 )
#      92 out_d = _cxn_to_soq_dict(
#      93     bloq.signature.rights(),
#      94     outgoing,
#      95     get_me=lambda cxn: cxn.left,
#      96     get_assign=_assign_outgoing,
#      97 )
# ---> 99 bloq.add_my_tensors(tn, binst, incoming=inc_d, outgoing=out_d)
#     100 if pos is not None:
#     101     fix[tuple([binst])] = pos[binst]
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/bloq.py:277, in Bloq.add_my_tensors(self, tn, tag, incoming, outgoing)
#     257 """Override this method to support native quimb simulation of this Bloq.
#     258
#     259 This method is responsible for adding a tensor corresponding to the unitary, state, or
#    (...)    273         the tensor network.
#     274 """
#     275 from qualtran.simulation.tensor import cbloq_as_contracted_tensor
# --> 277 cbloq = self.decompose_bloq()
#     278 tn.add(
#     279     cbloq_as_contracted_tensor(cbloq, incoming, outgoing, tags=[self.pretty_name(), tag])
#     280 )
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/bloq.py:142, in Bloq.decompose_bloq(self)
#     128 def decompose_bloq(self) -> 'CompositeBloq':
#     129     """Decompose this Bloq into its constituent parts contained in a CompositeBloq.
#     130
#     131     Bloq users can call this function to delve into the definition of a Bloq. If you're
#    (...)    140             `build_composite_bloq` returns `NotImplemented`.
#     141     """
# --> 142     return _decompose_from_build_composite_bloq(self)
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/bloq.py:51, in _decompose_from_build_composite_bloq(bloq)
#      48 from qualtran import BloqBuilder
#      50 bb, initial_soqs = BloqBuilder.from_signature(bloq.signature, add_registers_allowed=False)
# ---> 51 out_soqs = bloq.build_composite_bloq(bb=bb, **initial_soqs)
#      52 return bb.finalize(**out_soqs)
#
# File ~/Documents/Quantum/Qualtran-1/qualtran/bloqs/arithmetic/PhaseProduct.py:29, in Base2.build_composite_bloq(self, bb, x0, y0, x1, y1)
#      26 phi = self.phi
#      28 x1 = bb.add(CZPowGate(exponent=phi), q=[x0,x1])
# ---> 29 y1 = bb.add(CZPowGate(exponent=phi), q=[x0,y1])
#      30 x1 = bb.add(CZPowGate(exponent=phi), q=[y0,x1])
#      31 y1 = bb.add(CZPowGate(exponent=phi), q=[y0,y1])
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/composite_bloq.py:990, in BloqBuilder.add(self, bloq, **in_soqs)
#     963 def add(self, bloq: Bloq, **in_soqs: SoquetInT):
#     964     """Add a new bloq instance to the compute graph.
#     965
#     966     This is the primary method for building a composite bloq. Each call to `add` adds a
#    (...)    988             and irrespective of the order of `**in_soqs`.
#     989     """
# --> 990     outs = self.add_t(bloq, **in_soqs)
#     991     if len(outs) == 0:
#     992         return None
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/composite_bloq.py:942, in BloqBuilder.add_t(self, bloq, **in_soqs)
#     923 """Add a new bloq instance to the compute graph and always return a tuple of soquets.
#     924
#     925 This method will always return a tuple of soquets. See `BloqBuilder.add_d(..)` for a
#    (...)    939         to `bloq.signature` and irrespective of the order of `**in_soqs`.
#     940 """
#     941 binst = BloqInstance(bloq, i=self._new_binst_i())
# --> 942 return tuple(soq for _, soq in self._add_binst(binst, in_soqs=in_soqs))
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/composite_bloq.py:942, in <genexpr>(.0)
#     923 """Add a new bloq instance to the compute graph and always return a tuple of soquets.
#     924
#     925 This method will always return a tuple of soquets. See `BloqBuilder.add_d(..)` for a
#    (...)    939         to `bloq.signature` and irrespective of the order of `**in_soqs`.
#     940 """
#     941 binst = BloqInstance(bloq, i=self._new_binst_i())
# --> 942 return tuple(soq for _, soq in self._add_binst(binst, in_soqs=in_soqs))
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/composite_bloq.py:1013, in BloqBuilder._add_binst(self, binst, in_soqs)
#    1009 def _add(idxed_soq: Soquet, reg: Register, idx: Tuple[int, ...]):
#    1010     # close over `binst`
#    1011     return self._add_cxn(binst, idxed_soq, reg, idx)
# -> 1013 _process_soquets(
#    1014     registers=bloq.signature.lefts(), in_soqs=in_soqs, debug_str=str(bloq), func=_add
#    1015 )
#    1016 yield from (
#    1017     (reg.name, _reg_to_soq(binst, reg, available=self._available))
#    1018     for reg in bloq.signature.rights()
#    1019 )
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/composite_bloq.py:678, in _process_soquets(registers, in_soqs, debug_str, func)
#     676 idxed_soq = in_soq[li]
#     677 assert isinstance(idxed_soq, Soquet), idxed_soq
# --> 678 func(idxed_soq, reg, li)
#     679 if not check_dtypes_consistent(idxed_soq.reg.dtype, reg.dtype):
#     680     extra_str = (
#     681         f"{idxed_soq.reg.name}: {idxed_soq.reg.dtype} vs {reg.name}: {reg.dtype}"
#     682     )
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/composite_bloq.py:1011, in BloqBuilder._add_binst.<locals>._add(idxed_soq, reg, idx)
#    1009 def _add(idxed_soq: Soquet, reg: Register, idx: Tuple[int, ...]):
#    1010     # close over `binst`
# -> 1011     return self._add_cxn(binst, idxed_soq, reg, idx)
#
# File ~/Documents/Quantum/Qualtran-3/qualtran/_infra/composite_bloq.py:916, in BloqBuilder._add_cxn(self, binst, idxed_soq, reg, idx)
#     914 except KeyError:
#     915     bloq = binst if isinstance(binst, DanglingT) else binst.bloq
# --> 916     raise BloqError(
#     917         f"{idxed_soq} is not an available Soquet for `{bloq}.{reg.name}`."
#     918     ) from None
#     919 cxn = Connection(idxed_soq, Soquet(binst, reg, idx))
#     920 self._cxns.append(cxn)
#
# BloqError: LeftDangle.x0 is not an available Soquet for `CZ**pi/4.q`.
